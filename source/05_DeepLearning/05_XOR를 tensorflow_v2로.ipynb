# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성
from tensorflow.keras.layers import Input, Dense # layer층을 쌓을 때 필요

# %%
X_data = np.array([[0,0],
                   [0,1],
                   [1,0],
                   [1,1]])
y_data = np.array([[0],[1],[1],[0]])

# %%
# layer층 x_data 2개 -> 10 -> 20 -> 10 -> 1
model = Sequential()
# model.add(Input(shape=(2,))) # 입력층
model.add(Dense(units=10, # 출력
                input_dim=2, #입력
                activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid')) 
# 이진분류에서의 출력층 활성화 함수 sigmoid
# 다중분류에서의 출력층 활성화 함수 softmax(출력합을 1로)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 20)                220
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4. 모델 학습 과정 설정
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['binary_accuracy']) # 2진분류

# %%
# 5. 학습
hist = model.fit(X_data, y_data,
                 epochs=300, # 학습횟수
                # batch_size=4,
                 verbose=2) # 학습 로그 출력 (0:출력안됨, 1:간단, 2:상세)
# Out:
# Epoch 1/300
# 1/1 - 1s - loss: 0.6919 - binary_accuracy: 0.7500 - 594ms/epoch - 594ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.6904 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.6887 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.6872 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6859 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6848 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6836 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6823 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6809 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6796 - binary_accuracy: 0.2500 - 4ms/epoch - 4ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6785 - binary_accuracy: 0.2500 - 5ms/epoch - 5ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6775 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6764 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6752 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6740 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6729 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6718 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6706 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6696 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6684 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6676 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6668 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6658 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6648 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6636 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6624 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6615 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6605 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6596 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6586 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6576 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6566 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6555 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6545 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6535 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6523 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6514 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6505 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6495 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6486 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6476 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.6466 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.6456 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.6444 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.6433 - binary_accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.6423 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.6412 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.6401 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.6391 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.6380 - binary_accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.6368 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch
- binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.1476 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.1464 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.1453 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.1441 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.1430 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.1419 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.1408 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.1397 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.1386 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.1376 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.1366 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.1356 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.1345 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.1335 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.1325 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.1315 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.1306 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.1296 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.1287 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.1278 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.1269 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.1260 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.1251 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.1242 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.1233 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.1224 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.1216 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.1208 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.1199 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.1191 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.1183 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.1175 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step

# %%
# 5.학습과정살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'r', label='loss')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='center right')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax 생성
acc_ax.plot(hist.history['binary_accuracy'], 'b', label='binary_accuracy')
acc_ax.set_ylabel('binary_accuracy')
acc_ax.legend(bbox_to_anchor=(0.99, 0.4))

# %%
# 6. 학습평가
score = model.evaluate(X_data, y_data)
print('loss : ', score[0])
print('binary accuracy : ', score[1])
# Out:
# 1/1 [==============================] - 0s 219ms/step - loss: 0.1167 - binary_accuracy: 1.0000
# loss :  0.11670178174972534
# binary accuracy :  1.0

# %%
# 7. 모델 사용
model.predict(np.array([[0,1]])).round()
# Out:
# 1/1 [==============================] - 0s 121ms/step
# array([[1.]], dtype=float32)

# %%
model.predict(np.array([[0,1],
                        [1,1]])).round()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[1.],
#        [0.]], dtype=float32)
