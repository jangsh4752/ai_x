# %%
import os
import time
import json
import pandas as pd
from dotenv import load_dotenv
from openai import OpenAI

# ✅ .env에서 API 키 불러오기
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# ✅ 설정
topics = ["음식", "날씨", "취미"]
samples_per_topic = 20  # 예시 수 적게 설정 후 검증 (실행 전 1000 등으로 확장 가능)

# ✅ GPT 호출 함수
def generate_dialog(topic):
    prompt = f"""
'{topic}'에 대해 자연스럽고 일상적인 3턴 대화를 만들어줘. 
형식:
질문: ...
답변: ...
역질문: ...
맥락 흐름이 어색하지 않도록 자연스럽게 연결해줘.
"""
    try:
        chat_completion = client.chat.completions.create(
            model="gpt-4.1-nano",
            messages=[
                {"role": "system", "content": "너는 한국어 일상 대화에 능숙한 챗봇이야."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.8,
            max_tokens=300
        )
        content = chat_completion.choices[0].message.content
        lines = [line.strip() for line in content.split("\n") if line.strip()]
        if len(lines) == 3:
            q = lines[0].replace("질문:", "").strip()
            a = lines[1].replace("답변:", "").strip()
            f = lines[2].replace("역질문:", "").strip()
            if len(q) > 5 and len(a) > 5 and len(f) > 5:
                return {"주제": topic, "질문": q, "답변": a, "역질문": f}
    except Exception as e:
        print("⚠️ 오류 발생:", e)
    return None

# ✅ 생성 루프
all_rows = []
for topic in topics:
    print(f"🔹 '{topic}' 생성 중...")
    count = 0
    tries = 0
    while count < samples_per_topic and tries < samples_per_topic * 2:
        row = generate_dialog(topic)
        tries += 1
        if row:
            all_rows.append(row)
            count += 1
            print(f"✔️ {topic} {count}/{samples_per_topic}")
        time.sleep(1.1)  # rate limit 대비

# ✅ 데이터 저장
df = pd.DataFrame(all_rows).drop_duplicates(subset=["질문", "답변", "역질문"])
df.to_csv("gpt_smalltalk_ko.csv", index=False, encoding="utf-8-sig")
with open("gpt_smalltalk_ko.jsonl", "w", encoding="utf-8") as f:
    for _, row in df.iterrows():
        f.write(json.dumps(row.to_dict(), ensure_ascii=False) + "\n")

print(f"✅ 생성 완료! 총 {len(df)}개 저장됨")
# Out:
# 🔹 '음식' 생성 중...
# ✔️ 음식 1/20
# ✔️ 음식 2/20
# ✔️ 음식 3/20
# ✔️ 음식 4/20
# ✔️ 음식 5/20
# ✔️ 음식 6/20
# ✔️ 음식 7/20
# ✔️ 음식 8/20
# ✔️ 음식 9/20
# ✔️ 음식 10/20
# ✔️ 음식 11/20
# ✔️ 음식 12/20
# ✔️ 음식 13/20
# ✔️ 음식 14/20
# ✔️ 음식 15/20
# ✔️ 음식 16/20
# ✔️ 음식 17/20
# ✔️ 음식 18/20
# ✔️ 음식 19/20
# ✔️ 음식 20/20
# 🔹 '날씨' 생성 중...
# ✔️ 날씨 1/20
# ✔️ 날씨 2/20
# ✔️ 날씨 3/20
# ✔️ 날씨 4/20
# ✔️ 날씨 5/20
# ✔️ 날씨 6/20
# ✔️ 날씨 7/20
# ✔️ 날씨 8/20
# ✔️ 날씨 9/20
# ✔️ 날씨 10/20
# ✔️ 날씨 11/20
# ✔️ 날씨 12/20
# ✔️ 날씨 13/20
# ✔️ 날씨 14/20
# ✔️ 날씨 15/20
# ✔️ 날씨 16/20
# ✔️ 날씨 17/20
# ✔️ 날씨 18/20
# ✔️ 날씨 19/20
# ✔️ 날씨 20/20
# 🔹 '취미' 생성 중...
# ✔️ 취미 1/20
# ✔️ 취미 2/20
# ✔️ 취미 3/20
# ✔️ 취미 4/20
# ✔️ 취미 5/20
# ✔️ 취미 6/20
# ✔️ 취미 7/20
# ✔️ 취미 8/20
# ✔️ 취미 9/20
# ✔️ 취미 10/20
# ✔️ 취미 11/20
# ✔️ 취미 12/20
# ✔️ 취미 13/20
# ✔️ 취미 14/20
# ✔️ 취미 15/20
# ✔️ 취미 16/20
# ✔️ 취미 17/20
# ✔️ 취미 18/20
# ✔️ 취미 19/20
# ✔️ 취미 20/20
# ✅ 생성 완료! 총 60개 저장됨

# %%
# %pip install pandas asyncio dotenv openai tqdm datetime

# %pip install --upgrade pip

# %pip install --upgrade pandas

# %pip install --upgrade asyncio

# %pip install --upgrade dotenv

# %pip install --upgrade openai

# %pip install --upgrade tqdm

# %pip install --upgrade datetime
# Out:
# Collecting pandas
#   Downloading pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
#      --------------------------------------- 11.3/11.3 MB 65.1 MB/s eta 0:00:00
# Collecting asyncio
#   Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.8/101.8 kB 5.7 MB/s eta 0:00:00
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Collecting openai
#   Downloading openai-1.98.0-py3-none-any.whl (767 kB)
#      ------------------------------------- 767.7/767.7 kB 47.3 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#      ---------------------------------------- 52.6/52.6 kB ? eta 0:00:00
# Collecting numpy>=1.22.4
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#      --------------------------------------- 12.9/12.9 MB 65.1 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ------------------------------------- 347.8/347.8 kB 21.1 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ------------------------------------- 509.2/509.2 kB 33.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: sniffio in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (4.14.1)
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#      ------------------------------------- 444.8/444.8 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (4.9.0)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.10.0-cp310-cp310-win_amd64.whl (207 kB)
#      ---------------------------------------- 207.5/207.5 kB ? eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: colorama in d:\ai_x\2ndproject\.venv\lib\site-packages (from tqdm) (0.4.6)
# Collecting zope.interface
#   Downloading zope.interface-7.2-cp310-cp310-win_amd64.whl (211 kB)
#      ---------------------------------------- 211.9/211.9 kB ? eta 0:00:00
# Requirement already satisfied: idna>=2.8 in d:\ai_x\2ndproject\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\ai_x\2ndproject\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: certifi in d:\ai_x\2ndproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in d:\ai_x\2ndproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\ai_x\2ndproject\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 62.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in d:\ai_x\2ndproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: setuptools in d:\ai_x\2ndproject\.venv\lib\site-packages (from zope.interface->datetime) (65.5.0)
# Installing collected packages: pytz, asyncio, zope.interface, tzdata, typing-inspection, tqdm, python-dotenv, pydantic-core, numpy, jiter, distro, annotated-types, pydantic, pandas, dotenv, datetime, openai
# Successfully installed annotated-types-0.7.0 asyncio-3.4.3 datetime-5.5 distro-1.9.0 dotenv-0.9.9 jiter-0.10.0 numpy-2.2.6 openai-1.98.0 pandas-2.3.1 pydantic-2.11.7 pydantic-core-2.33.2 python-dotenv-1.1.1 pytz-2025.2 tqdm-4.67.1 typing-inspection-0.4.1 tzdata-2025.2 zope.interface-7.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pip in d:\ai_x\2ndproject\.venv\lib\site-packages (22.3.1)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 18.5 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-25.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in d:\ai_x\2ndproject\.venv\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.22.4 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\ai_x\2ndproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: asyncio in d:\ai_x\2ndproject\.venv\lib\site-packages (3.4.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: dotenv in d:\ai_x\2ndproject\.venv\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in d:\ai_x\2ndproject\.venv\lib\site-packages (from dotenv) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in d:\ai_x\2ndproject\.venv\lib\site-packages (1.98.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in d:\ai_x\2ndproject\.venv\lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\ai_x\2ndproject\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in d:\ai_x\2ndproject\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in d:\ai_x\2ndproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in d:\ai_x\2ndproject\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\ai_x\2ndproject\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\ai_x\2ndproject\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: colorama in d:\ai_x\2ndproject\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in d:\ai_x\2ndproject\.venv\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in d:\ai_x\2ndproject\.venv\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: datetime in d:\ai_x\2ndproject\.venv\lib\site-packages (5.5)
# Requirement already satisfied: zope.interface in d:\ai_x\2ndproject\.venv\lib\site-packages (from datetime) (7.2)
# Requirement already satisfied: pytz in d:\ai_x\2ndproject\.venv\lib\site-packages (from datetime) (2025.2)
# Requirement already satisfied: setuptools in d:\ai_x\2ndproject\.venv\lib\site-packages (from zope.interface->datetime) (65.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import nest_asyncio
import asyncio
from dotenv import load_dotenv
from openai import AsyncOpenAI
from tqdm.asyncio import tqdm_asyncio
from datetime import datetime

nest_asyncio.apply()
load_dotenv()
client = AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY"))

TOPICS = {
    "food": "음식에 관한 친근한 스몰토크",
    "weather": "날씨에 대한 자연스러운 대화",
    "hobby": "취미 관련 이야기를",
}

def build_conversation_prompt(topic_kr, n_turns=10):
    return f"""\
{topic_kr}를 주제로 자연스럽고 편안한 {n_turns}턴짜리 대화를 만들어줘.

조건:
- 질문 → 답변 → 다시 묻기 방식
- "A:", "B:" 로 시작하는 라인 형식
- 말투는 일상적이고 자연스럽게
- 중복된 표현 피하고 다양한 표현 사용
"""

async def generate_turns(topic_key, topic_kr, n_samples):
    unique_conversations = set()
    for _ in tqdm_asyncio(range(n_samples), desc=f"[{topic_key}] 생성 중"):
        try:
            prompt = build_conversation_prompt(topic_kr)
            response = await client.chat.completions.create(
                model="gpt-4o",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.85,
                max_tokens=1024,
            )
            result = response.choices[0].message.content.strip()
            unique_conversations.add(result)
        except Exception as e:
            print(f"[{topic_key}] 오류 발생: {e}")
    return list(unique_conversations)

async def main(total_per_topic=5000):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    for topic_key, topic_kr in TOPICS.items():
        print(f"\n🔹 '{topic_key}' 주제 생성 시작...")
        results = await generate_turns(topic_key, topic_kr, total_per_topic)
        df = pd.DataFrame({"topic": topic_key, "conversation": results})
        filename = f"{topic_key}_chats_{timestamp}.csv"
        df.to_csv(filename, index=False, encoding="utf-8-sig")
        print(f"✅ 저장 완료: {filename} (총 {len(df)}개)")

# ✅ Jupyter에서는 이렇게 실행
await main(total_per_topic=5000)
# Out:
# 🔹 'food' 주제 생성 시작...
# [food] 생성 중:   0%|          | 8/5000 [02:02<18:49:37, 13.58s/it]
